# %%
import sys
import os

# Add B_TEA folder to Python path
sys.path.append(os.path.abspath("../B_TEA"))

# Now import your function
from src.report_generator import run_report

# Path to your CSV
csv_path = "../B_TEA/data/new_expenses.csv"

# Run the report
run_report(csv_path)
# Out:
# Total expenses: £6,718.06
# Total income: £6,668.00
#
# Spending by Category:
# category
# Savings       4830.00
# General        426.01
# Expenses       410.00
# Bills          392.96
# Transport      200.80
# Family         200.00
# Eating out     101.05
# Shopping        77.19
# Groceries       59.55
# Transfers       12.00
# Holidays         8.50
# Name: amount, dtype: float64
# c:\Users\Atharv\Desktop\python-data-playground\B_TEA\src\report_generator.py:49: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=category_summary.values, y=category_summary.index, palette="viridis")
# Monthly Spending:
# month
# 2025-09    2235.70
# 2025-10    2176.21
# 2025-11    2306.15
# Freq: M, Name: amount, dtype: float64
# Unusually high transactions:
#          date   category  amount                  Name
# ...
